# %%
import pandas as pd

# %%
gw=pd.read_csv("gw.csv",dayfirst=True,index_col=0,parse_dates=['date'])

# %%
gw
# Out:
#                level
# date
# 1979-01-15  1.930000
# 1979-01-16  1.931667
# 1979-01-17  1.933333
# 1979-01-18  1.935000
# 1979-01-19  1.936667
# ...              ...
# 1993-12-23  1.147143
# 1993-12-24  1.142857
# 1993-12-25  1.138571
# 1993-12-26  1.134286
# 1993-12-27  1.130000
#
# [5461 rows x 1 columns]

# %%
gw.plot()

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df)

# %%
from pandas.plotting import autocorrelation_plot

# %%
autocorrelation_plot(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5461 entries, 1979-01-15 to 1993-12-27
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   level   5461 non-null   float64
# dtypes: float64(1)
# memory usage: 85.3 KB

# %%
df[["level"]].resample('1m').mean().plot()

# %%
df[["level"]].rolling(5).sum()
# Out:
#                level
# date
# 1979-01-15       NaN
# 1979-01-16       NaN
# 1979-01-17       NaN
# 1979-01-18       NaN
# 1979-01-19  9.666667
# ...              ...
# 1993-12-23  5.777922
# 1993-12-24  5.757143
# 1993-12-25  5.735714
# 1993-12-26  5.714286
# 1993-12-27  5.692857
#
# [5461 rows x 1 columns]

# %%
df
# Out:
#                level
# date
# 1979-01-15  1.930000
# 1979-01-16  1.931667
# 1979-01-17  1.933333
# 1979-01-18  1.935000
# 1979-01-19  1.936667
# ...              ...
# 1993-12-23  1.147143
# 1993-12-24  1.142857
# 1993-12-25  1.138571
# 1993-12-26  1.134286
# 1993-12-27  1.130000
#
# [5461 rows x 1 columns]

# %%
meteo.csv=pd.read_csv("meteo.csv",dayfirst=False,index_col=0,parse_dates=['date'])

# %%
meteo
# Out:
#             temp  prec   hum
# date
# 1966-01-01  -8.6   4.0  74.0
# 1966-01-02  -4.7   7.3  88.0
# 1966-01-03  -3.4   2.3  91.0
# 1966-01-04  -8.9   0.5  76.0
# 1966-01-05 -13.4   0.0  77.0
# ...          ...   ...   ...
# 2008-12-27   2.0   0.0  92.0
# 2008-12-28  -3.2   0.0  96.0
# 2008-12-29   0.8   0.0  91.0
# 2008-12-30   1.8   0.0  83.0
# 2008-12-31   1.8   0.3  80.0
#
# [15706 rows x 3 columns]

# %%
meteo.plot()

# %%
cols=["temp","prec","hum"]
grafiki=meteo[cols].plot(marker=".", alpha=0.5, color=["orange","blue","red"], 
                          linestyle=None, figsize=(11,9),subplots=True, grid=True)

# %%
df=meteo.join(gw, how="inner")

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#             temp  prec    hum     level
# date
# 1979-01-15  -1.7   0.2   83.0  1.930000
# 1979-01-16  -7.9   0.0   85.0  1.931667
# 1979-01-17  -7.8   0.0   82.0  1.933333
# 1979-01-18  -9.8   0.2   82.0  1.935000
# 1979-01-19 -12.8   0.0   83.0  1.936667
# ...          ...   ...    ...       ...
# 1993-12-23  -0.6   0.3   94.0  1.147143
# 1993-12-24   0.4   2.5   99.0  1.142857
# 1993-12-25  -1.5   0.0   95.0  1.138571
# 1993-12-26  -2.0   3.7   90.0  1.134286
# 1993-12-27  -0.5   2.9  100.0  1.130000
#
# [5461 rows x 4 columns]
