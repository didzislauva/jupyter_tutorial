# %%
import pandas as pd

# %%
df=pd.read_excel("Nokrisni_Dobele_2015-2020.xls", skiprows=1,parse_dates=["Datums \ Laiks"], index_col=0)

# %%
df["nokrišņu summa"]=df.sum(axis=1)

# %%
df=df[["nokrišņu summa"]]

# %%
df
# Out:
#                 nokrišņu summa
# Datums \ Laiks
# 2015-03-06                 0.0
# 2015-04-06                 0.0
# 2015-05-06                 0.0
# 2015-06-06                 0.0
# 2015-07-06                 0.0
# ...                        ...
# 2020-12-27                 0.0
# 2020-12-28                 0.6
# 2020-12-29                 2.3
# 2020-12-30                 4.0
# 2020-12-31                 2.6
#
# [1981 rows x 1 columns]

# %%
df2=pd.read_csv("station_data.csv", parse_dates=["Date"], index_col=0)

# %%
df2
# Out:
#             1_param  2_param  3_param  4_param  5_param   6_param  7_param  \
# Date
# 2014-08-18     0.51    0.033     0.84   0.0000   0.0320    5.6000   27.948
# 2014-09-15     0.27    0.160     0.30  62.8940  52.5000  580.8000   21.014
# 2014-09-27     1.54    3.492    20.48   0.8820   0.8500   44.5400   10.444
# 2014-10-13     0.00    7.688    41.60   3.7800   2.9280  163.0080   27.846
# 2014-10-26     0.13    5.670    13.72   2.1700   2.7200   29.2060   24.585
# ...             ...      ...      ...      ...      ...       ...      ...
# 2020-06-10     0.25    7.140    21.84   8.5652   3.3693       NaN   24.570
# 2020-07-12     0.66   25.560    48.00  28.2317  26.6526       NaN   15.708
# 2020-08-03     0.46   47.500    72.60   9.3366  11.9301   94.3353   24.732
# 2020-09-09     0.11   18.150    16.72  10.2528  11.2561       NaN   20.007
# 2020-10-01    33.20    3.100    17.29   1.8870   4.6690       NaN   17.424
#
# ...

# %%
df
# Out:
#                 nokrišņu summa
# Datums \ Laiks
# 2015-03-06                 0.0
# 2015-04-06                 0.0
# 2015-05-06                 0.0
# 2015-06-06                 0.0
# 2015-07-06                 0.0
# ...                        ...
# 2020-12-27                 0.0
# 2020-12-28                 0.6
# 2020-12-29                 2.3
# 2020-12-30                 4.0
# 2020-12-31                 2.6
#
# [1981 rows x 1 columns]
